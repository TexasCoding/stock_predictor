# %%
from pprint import pprint
from stock_predictor.polygon.polygon_financials import PolygonFinancials

financials = PolygonFinancials("DTE")

financials.get_financials()

# pprint(income_statement)
# Out:
# [09:51:27] {/home/jwest/Code/stock_predictor/src/stock_predictor/polygon/polygon_financials.py:115} WARNING - Error getting daily history for DTE: 'list' object has no attribute 'get'
# {'basic_average_shares': {'label': 'Basic Average Shares',
#                           'order': 4400,
#                           'unit': 'shares',
#                           'value': 206000000.0},
#  'basic_earnings_per_share': {'label': 'Basic Earnings Per Share',
#                               'order': 4200,
#                               'unit': 'USD / shares',
#                               'value': 6.77},
#  'benefits_costs_expenses': {'label': 'Benefits Costs and Expenses',
#                              'order': 200,
#                              'unit': 'USD',
#                              'value': 11179000000.0},
#  'costs_and_expenses': {'label': 'Costs And Expenses',
#                         'order': 600,
#                         'unit': 'USD',
# ...
