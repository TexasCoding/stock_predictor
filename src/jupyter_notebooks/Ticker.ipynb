# %%
from pprint import pprint
from stock_predictor.fmp_module.fmp_ticker import FmpTicker

FmpTicker().add_tickers()
# Out:
# Adding 4493 tickers to database...
# Output()
# [08:23:03] {/home/jwest/Code/stock_predictor/src/stock_predictor/fmp_module/fmp_ticker.py:192} WARNING - [bold red]Error retrieving FTRE data: list index out of range
# [08:23:06] {/home/jwest/Code/stock_predictor/src/stock_predictor/fmp_module/fmp_ticker.py:192} WARNING - [bold red]Error retrieving FTXH data: list index out of range
# [08:23:20] {/home/jwest/Code/stock_predictor/src/stock_predictor/fmp_module/fmp_ticker.py:192} WARNING - [bold red]Error retrieving DISV data: list index out of range
# [08:23:23] {/home/jwest/Code/stock_predictor/src/stock_predictor/fmp_module/fmp_ticker.py:192} WARNING - [bold red]Error retrieving DIV data: list index out of range
# [08:23:27] {/home/jwest/Code/stock_predictor/src/stock_predictor/fmp_module/fmp_ticker.py:192} WARNING - [bold red]Error retrieving FTXO data: list index out of range
# ...
